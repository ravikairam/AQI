# %%
import pandas as pd
import matplotlib as plt

# %% [markdown]
# # Combining all csv files into single excel file

# %%
import pandas as pd
import glob

path = r'E:\\Projects\\Krishnaik\\AQI-Project-master\\Data\\AQI' # use your path
all_files = glob.glob(path + "/*.csv")
li = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    li.append(df)

frame = pd.concat(li, axis=0, ignore_index=True)

# %%
frame
# Out:
#                       Date      Time  PM2.5 PM2.5 AQI
# 0                 1/1/2013   1:00 AM  324.4       238
# 1                 1/1/2013   2:00 AM  366.8       243
# 2                 1/1/2013   3:00 AM  290.7       250
# 3                 1/1/2013   4:00 AM  245.4       254
# 4                 1/1/2013   5:00 AM  220.3       259
# ...                    ...       ...    ...       ...
# 52507           30/12/2014   8:00 PM    336       378
# 52508           30/12/2014   9:00 PM    461       381
# 52509           30/12/2014  10:00 PM    417       385
# 52510           30/12/2014  11:00 PM    419       384
# 52511  30/12/2014 24:00 AM       NaN    475       382
#
# [52512 rows x 4 columns]

# %%
frame.to_csv("ravi.csv",sep=",")

# %% [markdown]
# # Managing each single file seperately

# %%
import pandas as pd
import glob

path = r'E:\\Projects\\Krishnaik\\AQI-Project-master\\Data\\AQI' # use your path
all_files = glob.glob(path + "/*.csv")
li = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    li.append(df)
    
#frame = pd.concat(li, axis=0, ignore_index=True)

# %%
li[0]
# Out:
#                      Date      Time  PM2.5 PM2.5 AQI
# 0                1/1/2013   1:00 AM  324.4       238
# 1                1/1/2013   2:00 AM  366.8       243
# 2                1/1/2013   3:00 AM  290.7       250
# 3                1/1/2013   4:00 AM  245.4       254
# 4                1/1/2013   5:00 AM  220.3       259
# ...                   ...       ...    ...       ...
# 8755           31/12/2013   8:00 PM    126       178
# 8756           31/12/2013   9:00 PM    124       175
# 8757           31/12/2013  10:00 PM    125       173
# 8758           31/12/2013  11:00 PM    210       170
# 8759  31/12/2013 24:00 AM       NaN    242       172
#
# [8760 rows x 4 columns]

# %%
pwd
# Out:
# 'E:\\'

# %% [markdown]
# # For one dataset

# %%
def avg_data_2013():
    temp_i = 0
    average =[]
    for rows in pd.read_csv('E:\\Projects\\Krishnaik\\AQI-Project-master\\Data\\AQI\\aqi2013.csv',chunksize=24):
        add_var=0
        avg=0.0
        data=[]
        df=pd.DataFrame(data=rows)
        for index,row in df.iterrows():
            data.append(row['PM2.5'])
        for i in data:
            if type(i) is float or type(i) is int:
                add_var =add_var+i
            elif type(i) is str:
                if i!='NoData' and i!='PwrFail' and i!='---' and i!='InVld':
                    temp = float(i)
                    add_var =add_var+temp
        avg=add_var/24
        temp_i = temp_i+1
        average.append(avg)
    return(average)
        
if __name__=="__main__":
    avg_data_2013()

# %%
avg_data_2013()
# Out:
# [284.79583333333335,
#  219.72083333333333,
#  182.1875,
#  115.28749999999998,
#  0.0,
#  12.379166666666668,
#  154.03750000000002,
#  223.20833333333334,
#  200.64583333333337,
#  154.875,
#  129.38749999999996,
#  224.2458333333333,
#  285.22499999999997,
#  236.82499999999996,
#  276.90833333333336,
#  245.65,
#  218.67083333333326,
#  47.82500000000001,
#  108.0,
#  107.625,
#  125.89166666666667,
#  179.3083333333333,
#  239.85,
#  220.1916666666667,
#  181.01250000000005,
#  152.55416666666667,
#  152.32083333333335,
#  171.42916666666665,
#  251.375,
#  251.82916666666668,
#  319.7375,
#  332.7083333333333,
#  279.59999999999997,
#  179.11666666666667,
#  166.29999999999998,
#  78.25416666666666,
#  54.958333333333336,
#  54.791666666666664,
#  93.375,
#  103.0,
#  211.125,
#  192.29166666666666,
#  152.0,
#  132.20833333333334,
#  127.70833333333333,
#  109.33333333333333,
#  0.0,
#  0.0,
#  0.0,
#  56.458333333333336,
#  135.83333333333334,
#  122.5,
# ...

# %% [markdown]
# # All files in one and parse

# %%
def avg_data_AQI():
    temp_i = 0
    average =[]
    path = r'E:\\Projects\\Krishnaik\\AQI-Project-master\\Data\\AQI' # use your path
    all_files = glob.glob(path + "/*.csv")
    li = []

    for filename in all_files:
        for rows in pd.read_csv(filename,chunksize=24):
        #for rows in pd.read_csv('E:\\Projects\\Krishnaik\\AQI-Project-master\\Data\\AQI\\aqi2013.csv',chunksize=24):
            add_var=0
            avg=0.0
            data=[]
            df=pd.DataFrame(data=rows)
            for index,row in df.iterrows():
                data.append(row['PM2.5'])
            for i in data:
                if type(i) is float or type(i) is int:
                    add_var =add_var+i
                elif type(i) is str:
                    if i!='NoData' and i!='PwrFail' and i!='---' and i!='InVld':
                        temp = float(i)
                        add_var =add_var+temp
            avg=add_var/24
            temp_i = temp_i+1
            average.append(avg)
    return(average)
        
if __name__=="__main__":
    avg_data_AQI()

# %%
avg_data_AQI()
# Out:
# [284.79583333333335,
#  219.72083333333333,
#  182.1875,
#  115.28749999999998,
#  0.0,
#  12.379166666666668,
#  154.03750000000002,
#  223.20833333333334,
#  200.64583333333337,
#  154.875,
#  129.38749999999996,
#  224.2458333333333,
#  285.22499999999997,
#  236.82499999999996,
#  276.90833333333336,
#  245.65,
#  218.67083333333326,
#  47.82500000000001,
#  108.0,
#  107.625,
#  125.89166666666667,
#  179.3083333333333,
#  239.85,
#  220.1916666666667,
#  181.01250000000005,
#  152.55416666666667,
#  152.32083333333335,
#  171.42916666666665,
#  251.375,
#  251.82916666666668,
#  319.7375,
#  332.7083333333333,
#  279.59999999999997,
#  179.11666666666667,
#  166.29999999999998,
#  78.25416666666666,
#  54.958333333333336,
#  54.791666666666664,
#  93.375,
#  103.0,
#  211.125,
#  192.29166666666666,
#  152.0,
#  132.20833333333334,
#  127.70833333333333,
#  109.33333333333333,
#  0.0,
#  0.0,
#  0.0,
#  56.458333333333336,
#  135.83333333333334,
#  122.5,
# ...

# %%
def avg_data_AQI(folder_path):
    temp_i = 0
    average =[]
    for rows in pd.read_csv('E:\\Projects\\Krishnaik\\AQI-Project-master\\Data\\AQI\\aqi2013.csv',chunksize=24):
        add_var=0
        avg=0.0
        data=[]
        df=pd.DataFrame(data=rows)
        for index,row in df.iterrows():
            data.append(row['PM2.5'])
        for i in data:
            if type(i) is float or type(i) is int:
                add_var =add_var+i
            elif type(i) is str:
                if i!='NoData' and i!='PwrFail' and i!='---' and i!='InVld':
                    temp = float(i)
                    add_var =add_var+temp
        avg=add_var/24
        temp_i = temp_i+1
        average.append(avg)
    return(average)
        
if __name__=="__main__":
    avg_data_2013()

# %%
for rows in pd.read_csv('E:\\Projects\\Krishnaik\\AQI-Project-master\\Data\\AQI\\aqi2013.csv',chunksize=24):
     add_var=0
     avg=0.0
     data=[]
     df=pd.DataFrame(data=rows)

# %%
print(df)
# Out:
#                      Date      Time  PM2.5 PM2.5 AQI
# 8736           31/12/2013   1:00 AM    125    NoData
# 8737           31/12/2013   2:00 AM     86    NoData
# 8738           31/12/2013   3:00 AM     65       248
# 8739           31/12/2013   4:00 AM     54       241
# 8740           31/12/2013   5:00 AM     56       234
# 8741           31/12/2013   6:00 AM     55       228
# 8742           31/12/2013   7:00 AM     70       223
# 8743           31/12/2013   8:00 AM    105       218
# 8744           31/12/2013   9:00 AM    116       216
# 8745           31/12/2013  10:00 AM    122       202
# 8746           31/12/2013  11:00 AM    130       195
# 8747           31/12/2013  12:00 PM    132       191
# 8748           31/12/2013   1:00 PM    119       189
# 8749           31/12/2013   2:00 PM    103       189
# 8750           31/12/2013   3:00 PM     74       188
# 8751           31/12/2013   4:00 PM     56       187
# 8752           31/12/2013   5:00 PM     74       184
# ...

# %%
for index,row in df.iterrows():
            data.append(row['PM2.5'])

# %%
data
# Out:
# [125,
#  86,
#  65,
#  54,
#  56,
#  55,
#  70,
#  105,
#  116,
#  122,
#  130,
#  132,
#  119,
#  103,
#  74,
#  56,
#  74,
#  93,
#  132,
#  126,
#  124,
#  125,
#  210,
#  242]
